# %%
#_____load labs

import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\Rizwan\\Desktop\\train.csv")

# %% [markdown]
# # Explore the data

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape  #_______demension of data
# Out:
# (1460, 81)

# %%
df.size#_______total size
# Out:
# 118260

# %% [markdown]
# # set all columns and rows

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.sample(6)#_________to get random sample
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1185  1186          50       RL         60.0     9738   Pave   NaN      Reg
# 1018  1019          80       RL          NaN    10784   Pave   NaN      IR1
# 660    661          60       RL          NaN    12384   Pave   NaN      Reg
# 123    124         120       RL         55.0     7892   Pave   NaN      Reg
# 723    724          50       RL         60.0     8172   Pave   NaN      Reg
# 264    265          30       RM         30.0     5232   Pave  Grvl      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1185         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1018         Lvl    AllPub       FR2       Gtl      Gilbert       Norm
# 660          Lvl    AllPub   CulDSac       Gtl       NWAmes       Norm
# 123          Lvl    AllPub    Inside       Gtl      SawyerW       Norm
# 723          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# ...

# %%
df.info() #_____________info about features
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# # Check nulls vals

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# # taking persage of missing val

# %%
miss_val_pers=df.isnull().sum()/df.shape[0]*100

# %%
miss_val_pers
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %% [markdown]
# # pick the missing val cols

# %%
miss_val_col=miss_val_pers[miss_val_pers>20].keys()

# %%
miss_val_col
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %% [markdown]
# # drop missing val cols >20%

# %%
df_drop_col=df.drop(columns=miss_val_col)

# %%
df_drop_col.shape
# Out:
# (1460, 76)

# %% [markdown]
# # select num datas

# %%
df_numeric=df_drop_col.select_dtypes(include=['int64','float64'])

# %%
df_numeric.sample(7)
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 1311  1312          20         68.0     8814            7            5
# 1123  1124          20         50.0     9405            5            9
# 589    590          40         50.0     9100            5            6
# 713    714         190         60.0     9873            4            5
# 133    134          20          NaN     6853            8            5
# 837    838         160         21.0     1680            6            5
# 109    110          20        105.0    11751            6            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 1311       2005          2007        80.0         925           0        349
# 1123       1947          2008         0.0           0           0        698
# 589        1930          1960         0.0           0           0        742
# 713        1970          1970       160.0         789           0        171
# ...

# %%
df_numeric.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# # shows missing values in graphs

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_numeric)#plot ans see mising val after  drop
# Out:
# <Axes: >

# %%
df_numeric[df_numeric.isnull().any(axis=1)]#drop missing val about rows
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 7        8          60          NaN    10382            7            6
# 12      13          20          NaN    12968            5            6
# 14      15          20          NaN    10920            6            5
# 16      17          20          NaN    11241            6            7
# 24      25          20          NaN     8246            5            8
# 31      32          20          NaN     8544            5            6
# 39      40          90         65.0     6040            4            5
# 42      43          85          NaN     9180            5            7
# 43      44          20          NaN     9200            5            6
# 48      49         190         33.0     4456            4            5
# 50      51          60          NaN    13869            6            6
# 64      65          60          NaN     9375            7            5
# ...

# %%
df_numeric.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
missing_num_val=[var for var in df_numeric.columns if df_numeric[var].isnull().sum()>0]#store all missing val in var

# %%
missing_num_val
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %% [markdown]
# # making baning

# %%
plt.figure(figsize=(16,16))#check dist of missing data val
sns.set()
for i, var in enumerate(missing_num_val):
    plt.subplot(2,2,i+1)
    sns.histplot(df_numeric[var], bins=20, kde_kws={'linewidth':5, 'color':'k'})

# %%
df_mean=df_numeric.fillna(df_numeric.mean())#fill missing val with mean of missing vals
df_mean
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60    65.000000     8450            7            5
# 1        2          20    80.000000     9600            6            8
# 2        3          60    68.000000    11250            7            5
# 3        4          70    60.000000     9550            7            5
# 4        5          60    84.000000    14260            8            5
# 5        6          50    85.000000    14115            5            5
# 6        7          20    75.000000    10084            8            5
# 7        8          60    70.049958    10382            7            6
# 8        9          50    51.000000     6120            7            5
# 9       10         190    50.000000     7420            5            6
# 10      11          20    70.000000    11200            5            5
# 11      12          60    85.000000    11924            9            5
# ...

# %%
df_mean.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Data clean with means

# %% [markdown]
# # Data clean with modes

# %%
df_median=df_numeric.fillna(df_numeric.median())#ffill missing val with meading of missing vlas

# %%
df_median.sample(6)
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 665    666          60        106.0    11194            8            5
# 1220  1221          20         66.0     7800            5            5
# 254    255          20         70.0     8400            5            6
# 587    588          85         74.0     8740            5            6
# 1404  1405          50         60.0    10410            3            4
# 730    731         120         39.0     5389            8            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 665        2000          2000        40.0           0           0       1406
# 1220       1964          1964         0.0         312         600          0
# 254        1957          1957         0.0         922           0        392
# 587        1982          1982         0.0         672           0        168
# 1404       1915          1950         0.0           0           0        672
# ...

# %%
df_median.isnull().sum().sum()#____________check nulss vals
# Out:
# 0

# %% [markdown]
# # check the change in distrebution of data

# %%
plt.figure(figsize=(16,16))#check dist of data after fill missing val with medien 
sns.set()
for i, var in enumerate(missing_num_val):
    plt.subplot(2,2,i+1)
    sns.histplot(df_median[var], bins=20, kde=True)

# %%
plt.figure(figsize=(16,16))#check dist oof data after filling missing val with mean of missing val 
sns.set()
for i, var in enumerate(missing_num_val):
    plt.subplot(2,2,i+1)
    sns.histplot(df_mean[var], bins=20,kde=True,color="g")

# %%
plt.figure(figsize=(16,16))#check dist oof data after filling missing val with mean of missing val 
sns.set()
for i, var in enumerate(missing_num_val):
    plt.subplot(2,2,i+1)
    sns.histplot(df_mean[var], bins=20,kde=True,label="mean")
    sns.histplot(df_median[var], bins=20, kde=True,label="medien")
    
    sns.histplot(df_numeric[var], bins=20, kde_kws={'linewidth':5, 'color':'k'},label="Original")
    plt.legend()

# %% [raw]
# Diff bt  original and mean medien filling

# %% [markdown]
# # chechk the outliers

# %%
for i,var in enumerate(missing_num_val):
    plt.figure(figsize=(10,10))
    plt.subplot(3,1,1)
    sns.boxplot(df[var])
    plt.subplot(3,1,1)
    sns.boxplot(df_mean[var])
    plt.subplot(3,1,1)
    sns.boxplot(df_median[var])
